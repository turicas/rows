# %% [markdown]
# # Rows in Jupyter

# %%
import rows

# %%
data = rows.import_from_csv("../data/tesouro-direto.csv")

# %%
rows.head(data)
# Out:
# <table>
#
#   <thead>
#     <tr>
#       <th> timestamp </th>
#       <th> titulo </th>
#       <th> vencimento </th>
#       <th> taxa_compra </th>
#       <th> taxa_venda </th>
#       <th> preco_compra </th>
#       <th> preco_venda </th>
#     </tr>
#   </thead>
#
#   <tbody>
#
#         <tr class="even">
#       <td> 2015-11-06T17:43:00 </td>
#       <td> Tesouro Prefixado 2016 (LTN) </td>
#       <td> 2016-01-01 </td>
#       <td> 7.02% </td>
#       <td> 14.27% </td>
#       <td> 0.0 </td>
#       <td> 980.08 </td>
#     </tr>
#
#     <tr class="odd">
#       <td> 2015-11-06T17:43:00 </td>
#       <td> Tesouro Prefixado com Juros Semestrais 2017 (NTNF) </td>
#       <td> 2017-01-01 </td>
#       <td> 7.02% </td>
#       <td> 15.32% </td>
#       <td> 0.0 </td>
#       <td> 982.94 </td>
#     </tr>
#
#     <tr class="even">
#       <td> 2015-11-06T17:43:00 </td>
#       <td> Tesouro Prefixado 2017 (LTN) </td>
#       <td> 2017-01-01 </td>
#       <td> 7.02% </td>
# ...

# %%
rows.head(data, 30)
# Out:
# <table>
#
#   <thead>
#     <tr>
#       <th> timestamp </th>
#       <th> titulo </th>
#       <th> vencimento </th>
#       <th> taxa_compra </th>
#       <th> taxa_venda </th>
#       <th> preco_compra </th>
#       <th> preco_venda </th>
#     </tr>
#   </thead>
#
#   <tbody>
#
#         <tr class="odd">
#       <td> 2015-11-06T17:43:00 </td>
#       <td> Tesouro Prefixado com Juros Semestrais 2021 (NTNF) </td>
#       <td> 2021-01-01 </td>
#       <td> 7.02% </td>
#       <td> 15.61% </td>
#       <td> 0.0 </td>
#       <td> 851.42 </td>
#     </tr>
#
#     <tr class="even">
#       <td> 2015-11-06T17:43:00 </td>
#       <td> Tesouro Prefixado com Juros Semestrais 2023 (NTNF) </td>
#       <td> 2023-01-01 </td>
#       <td> 7.02% </td>
#       <td> 15.61% </td>
#       <td> 0.0 </td>
#       <td> 809.9 </td>
#     </tr>
#
#     <tr class="odd">
#       <td> 2015-11-06T17:43:00 </td>
#       <td> Tesouro Prefixado com Juros Semestrais 2025 (NTNF) </td>
# ...

# %%
rows.head(data, 5)
# Out:
# <table>
#
#   <thead>
#     <tr>
#       <th> timestamp </th>
#       <th> titulo </th>
#       <th> vencimento </th>
#       <th> taxa_compra </th>
#       <th> taxa_venda </th>
#       <th> preco_compra </th>
#       <th> preco_venda </th>
#     </tr>
#   </thead>
#
#   <tbody>
#
#     <tr class="odd">
#       <td> 2015-11-06T17:43:00 </td>
#       <td> Tesouro IPCA+ com Juros Semestrais 2017 (NTNB) </td>
#       <td> 2017-05-15 </td>
#       <td> 7.02% </td>
#       <td> 6.3% </td>
#       <td> 0.0 </td>
#       <td> 2792.97 </td>
#     </tr>
#
#     <tbody>
#
# <table>

# %%
rows.head(data, 1)
# Out:
# <table>
#
#   <thead>
#     <tr>
#       <th> timestamp </th>
#       <th> titulo </th>
#       <th> vencimento </th>
#       <th> taxa_compra </th>
#       <th> taxa_venda </th>
#       <th> preco_compra </th>
#       <th> preco_venda </th>
#     </tr>
#   </thead>
#
#   <tbody>
#
#     <tr class="odd">
#       <td> 2015-11-06T17:43:00 </td>
#       <td> Tesouro IPCA+ com Juros Semestrais 2017 (NTNB) </td>
#       <td> 2017-05-15 </td>
#       <td> 7.02% </td>
#       <td> 6.3% </td>
#       <td> 0.0 </td>
#       <td> 2792.97 </td>
#     </tr>
#
#     <tbody>
#
# <table>

# %%
rows.tail(data)
# Out:
# <table>
#
#   <thead>
#     <tr>
#       <th> timestamp </th>
#       <th> titulo </th>
#       <th> vencimento </th>
#       <th> taxa_compra </th>
#       <th> taxa_venda </th>
#       <th> preco_compra </th>
#       <th> preco_venda </th>
#     </tr>
#   </thead>
#
#   <tbody>
#
#         <tr class="even">
#       <td> 2015-11-06T17:43:00 </td>
#       <td> Tesouro Prefixado 2016 (LTN) </td>
#       <td> 2016-01-01 </td>
#       <td> 7.02% </td>
#       <td> 14.27% </td>
#       <td> 0.0 </td>
#       <td> 980.08 </td>
#     </tr>
#
#     <tr class="odd">
#       <td> 2015-11-06T17:43:00 </td>
#       <td> Tesouro Prefixado com Juros Semestrais 2017 (NTNF) </td>
#       <td> 2017-01-01 </td>
#       <td> 7.02% </td>
#       <td> 15.32% </td>
#       <td> 0.0 </td>
#       <td> 982.94 </td>
#     </tr>
#
#     <tr class="even">
#       <td> 2015-11-06T17:43:00 </td>
#       <td> Tesouro Prefixado 2017 (LTN) </td>
#       <td> 2017-01-01 </td>
#       <td> 7.02% </td>
# ...

# %%
rows.tail(data, 30)
# Out:
# <table>
#
#   <thead>
#     <tr>
#       <th> timestamp </th>
#       <th> titulo </th>
#       <th> vencimento </th>
#       <th> taxa_compra </th>
#       <th> taxa_venda </th>
#       <th> preco_compra </th>
#       <th> preco_venda </th>
#     </tr>
#   </thead>
#
#   <tbody>
#
#     <tr class="odd">
#       <td> 2015-11-06T17:43:00 </td>
#       <td> Tesouro IPCA+ com Juros Semestrais 2017 (NTNB) </td>
#       <td> 2017-05-15 </td>
#       <td> 7.02% </td>
#       <td> 6.3% </td>
#       <td> 0.0 </td>
#       <td> 2792.97 </td>
#     </tr>
#
#     <tr class="even">
#       <td> 2015-11-06T17:43:00 </td>
#       <td> Tesouro IPCA+ 2019 (NTNB Princ) </td>
#       <td> 2019-05-15 </td>
#       <td> 7.02% </td>
#       <td> 7.06% </td>
#       <td> 2150.33 </td>
#       <td> 2147.53 </td>
#     </tr>
#
#     <tr class="odd">
#       <td> 2015-11-06T17:43:00 </td>
#       <td> Tesouro IPCA+ com Juros Semestrais 2020 (NTNB) </td>
#       <td> 2020-08-15 </td>
# ...

# %%
rows.tail(data, 5)
# Out:
# <table>
#
#   <thead>
#     <tr>
#       <th> timestamp </th>
#       <th> titulo </th>
#       <th> vencimento </th>
#       <th> taxa_compra </th>
#       <th> taxa_venda </th>
#       <th> preco_compra </th>
#       <th> preco_venda </th>
#     </tr>
#   </thead>
#
#   <tbody>
#
#         <tr class="odd">
#       <td> 2015-11-06T17:43:00 </td>
#       <td> Tesouro Prefixado com Juros Semestrais 2021 (NTNF) </td>
#       <td> 2021-01-01 </td>
#       <td> 7.02% </td>
#       <td> 15.61% </td>
#       <td> 0.0 </td>
#       <td> 851.42 </td>
#     </tr>
#
#     <tr class="even">
#       <td> 2015-11-06T17:43:00 </td>
#       <td> Tesouro Prefixado com Juros Semestrais 2023 (NTNF) </td>
#       <td> 2023-01-01 </td>
#       <td> 7.02% </td>
#       <td> 15.61% </td>
#       <td> 0.0 </td>
#       <td> 809.9 </td>
#     </tr>
#
#     <tr class="odd">
#       <td> 2015-11-06T17:43:00 </td>
#       <td> Tesouro Prefixado com Juros Semestrais 2025 (NTNF) </td>
# ...

# %%
rows.tail(data, 1)
# Out:
# <table>
#
#   <thead>
#     <tr>
#       <th> timestamp </th>
#       <th> titulo </th>
#       <th> vencimento </th>
#       <th> taxa_compra </th>
#       <th> taxa_venda </th>
#       <th> preco_compra </th>
#       <th> preco_venda </th>
#     </tr>
#   </thead>
#
#   <tbody>
#
#         <tr class="odd">
#       <td> 2015-11-06T17:43:00 </td>
#       <td> Tesouro Selic 2021 (LFT) </td>
#       <td> 2021-03-01 </td>
#       <td> 0.00% </td>
#       <td> 0.04% </td>
#       <td> 7261.57 </td>
#       <td> 7246.25 </td>
#     </tr>
#
#   </tbody>
#
# </table>
